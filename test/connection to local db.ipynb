# %%
from sqlalchemy import create_engine
import pandas as pd
import pymssql
# Out:
# C:\Users\infomax\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# engine = create_engine('mssql+pymssql://mquant:solution1@172.32.1.100/MQUANT?charset=utf8', encoding='utf-8')#, echo=True)
engine = create_engine('postgresql://postgres:kkangse1@35.193.204.14/postgres')

# %%
engine.table_names()
# Out:
# ['django_migrations',
#  'django_content_type',
#  'auth_permission',
#  'auth_group',
#  'auth_group_permissions',
#  'getchapp_customemailuser',
#  'getchapp_customemailuser_groups',
#  'getchapp_customemailuser_user_permissions',
#  'getchapp_profile',
#  'getchapp_post',
#  'getchapp_item',
#  'getchapp_channel',
#  'getchapp_brand',
#  'account_emailaddress',
#  'account_emailconfirmation',
#  'django_admin_log',
#  'django_session',
#  'socialaccount_socialaccount',
#  'socialaccount_socialapp_sites',
#  'django_site',
#  'socialaccount_socialtoken',
#  'socialaccount_socialapp']

# %%
with engine.connect() as conn, conn.begin():
    #data = pd.read_sql_table('Fund_Universe_TB', conn)
    data = pd.read_sql_table('getchapp_brand', conn)

# %%
data
# Out:
#       id          name                        keywords  \
# 0      1         zucca                       zucca, 쥬카
# 1      2          zara                        zara, 자라
# 2      3  ystrdystmrrw        ystrdystmrrw, 예스터데이즈투모로우
# 3      4  yojiyamamoto      yojiyamamoto, yoji, 요지야마모토
# 4      5         yeezy                       yeezy, 이지
# ..   ...           ...                             ...
# 319  320          aape                       aape, 에이프
# 320  321   99percentis            99percentis, 99퍼센트이즈
# 321  322      8seconds  8seconds, 8second, 에잇세컨즈, 8세컨즈
# 322  323   1017alyx9sm          1017alyx9sm, alyx, 알릭스
# 323  324          032c                      032c, 032씨
#
#                           created_at  nlikes fullname_kr     fullname_en  \
# 0   2019-11-26 07:11:17.124728+00:00       0          쥬카           zucca
# 1   2019-11-26 07:11:17.698582+00:00       0          자라            zara
# 2   2019-11-26 07:11:18.084561+00:00       0  예스터데이즈투모로우  ystrdy's tmrrw
# 3   2019-11-26 07:11:18.466519+00:00       0      요지야마모토    yojiyamamoto
# 4   2019-11-26 07:11:18.853065+00:00       0          이지           yeezy
# ..                               ...     ...         ...             ...
# 319 2019-11-26 07:13:18.653600+00:00       0         에이프            aape
# 320 2019-11-26 07:13:19.048866+00:00       0     99퍼센트이즈          99% is
# 321 2019-11-26 07:13:19.418262+00:00       0       에잇세컨즈        8seconds
# 322 2019-11-26 07:13:19.795504+00:00       0         알릭스     1017alyx9sm
# 323 2019-11-26 07:13:20.170576+00:00       0        032씨            032c
#
#     origin      category description                          image master_id
# 0      JPN  contemporary                     brand_images\zucca.jpg      None
# 1      ESP           spa                      brand_images\zara.jpg      None
# 2      JPN      designer              brand_images\ystrdystmrrw.jpg      None
# 3      JPN        luxury              brand_images\yojiyamamoto.jpg      None
# 4      USA      designer                     brand_images\yeezy.jpg      None
# ..     ...           ...         ...                            ...       ...
# 319    JPN      designer                      brand_images\aape.jpg      None
# 320    KOR      designer               brand_images\99percentis.jpg      None
# 321    KOR           spa                  brand_images\8seconds.gif      None
# 322    USA      designer               brand_images\1017alyx9sm.jpg      None
# 323    GER      designer                      brand_images\032c.jpg      None
#
# [324 rows x 12 columns]

# %%
engine.table_names()
# Out:
# ['BMcomp_Dat_TB',
#  'DB_Info_TB',
#  'DB_info_TB_Q1',
#  'Display_Code_TB',
#  'EcoModel_Detail_TB',
#  'EcoModel_Factor_TB',
#  'EcoModel_Idx_TB',
#  'EcoModel_Mast_TB',
#  'Factor_Dat_TB',
#  'Factor_IC_TB',
#  'Factor_Mast_TB',
#  'FixedRiskBudget_TB',
#  'Fund_Beneficiary_TB',
#  'Fund_Detail_TB',
#  'Fund_IsinHist_TB',
#  'Fund_Mast_TB',
#  'Fund_PLdecompose_TB',
#  'Fund_Result_TB',
#  'Fund_RiskBudget_TB',
#  'Fund_RiskBudget_TB2',
#  'Fund_RiskBudget_TB3',
#  'Fund_Sensitivity_TB',
#  'Fund_TempTrade_TB',
#  'Fund_Universe_Hist',
#  'Fund_Universe_TB',
#  'Fund_Universe_TB_temp',
#  'Fundamental_Data_TB',
#  'Fundamental_Mast_TB',
#  'Index_Bond_Dat_TB',
#  'Index_ETF_Dat_TB',
#  'Index_Idx_Dat_TB',
#  'Index_Mapping_TB',
#  'Index_Mast_TB',
#  'Index_Sensitivity_TB',
#  'Macro_Dictionary_TB',
#  'Macro_IdxComp_TB',
#  'Macro_Mast_TB',
#  'Macro_Schedule_TB',
#  'MktComment_Hist_TB',
#  'Model_Detail_TB',
#  'Model_History_TB',
#  'Model_Result_TB',
#  'Otherfund_Asset_TB',
#  'Otherfund_TB',
#  'RawData_macro_TB',
#  'RawData_macroConsensus_TB',
#  'sysdiagrams',
#  'Temp_Date',
#  'Temp_ETF_Universe',
#  'Temp_JD_Data',
#  'Temp_MacroCode_TB',
#  'Temp_MacroMap_TB',
#  'Temp_MacroMast_TB',
#  'Temp_MacroRaw_TB',
#  'View_Detail_TB',
#  'z_phase_TB',
#  'z_phaseSub_TB',
#  'z_Pivot_Test',
#  'z_Voltest',
#  'zCodeMapping_TB',
#  'zGDP_TB',
#  'zIndex_Idx_Dat_TB',
#  'zInput_test',
#  'zInputAdd_test',
#  'zOtherfund_Asset_TB',
#  'zOtherfund_TB',
#  'zRawData_macro_TB',
#  'zRawData_TB',
#  'zRawDate_Mast_TB',
#  'zRawMast_TB']
