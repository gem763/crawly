# %%
from sqlalchemy import create_engine
import pandas as pd
import pymssql

# %%
engine = create_engine('mssql+pymssql://mquant:solution1@172.32.1.100/MQUANT?charset=utf8', encoding='utf-8')#, echo=True)
# engine = create_engine('postgresql://postgres:kkangse1@35.193.204.14/postgres')

# %%
engine.table_names()
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# src\pymssql.pyx in pymssql.connect()
#
# src\_mssql.pyx in _mssql.connect()
#
# src\_mssql.pyx in _mssql.MSSQLConnection.__init__()
#
# src\_mssql.pyx in _mssql.maybe_raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (172.32.1.100:1433)\nNet-Lib error during Unknown error (10060)\nDB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (172.32.1.100:1433)\nNet-Lib error during Unknown error (10060)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
with engine.connect() as conn, conn.begin():
    data = pd.read_sql_table('Fund_Universe_TB', conn)
    #data = pd.read_sql_table('getchapp_brand', conn)
# Out:
# ---------------------------------------------------------------------------
# MSSQLDatabaseException                    Traceback (most recent call last)
# src\pymssql.pyx in pymssql.connect()
#
# src\_mssql.pyx in _mssql.connect()
#
# src\_mssql.pyx in _mssql.MSSQLConnection.__init__()
#
# src\_mssql.pyx in _mssql.maybe_raise_MSSQLDatabaseException()
#
# MSSQLDatabaseException: (20009, b'DB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (172.32.1.100:1433)\nNet-Lib error during Unknown error (10060)\nDB-Lib error message 20009, severity 9:\nUnable to connect: Adaptive Server is unavailable or does not exist (172.32.1.100:1433)\nNet-Lib error during Unknown error (10060)\n')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# ...

# %%
data
# Out:
#       id          name                        keywords  \
# 0      1         zucca                       zucca, 쥬카
# 1      2          zara                        zara, 자라
# 2      3  ystrdystmrrw        ystrdystmrrw, 예스터데이즈투모로우
# 3      4  yojiyamamoto      yojiyamamoto, yoji, 요지야마모토
# 4      5         yeezy                       yeezy, 이지
# ..   ...           ...                             ...
# 319  320          aape                       aape, 에이프
# 320  321   99percentis            99percentis, 99퍼센트이즈
# 321  322      8seconds  8seconds, 8second, 에잇세컨즈, 8세컨즈
# 322  323   1017alyx9sm          1017alyx9sm, alyx, 알릭스
# 323  324          032c                      032c, 032씨
#
#                           created_at  nlikes fullname_kr     fullname_en  \
# 0   2019-11-26 07:11:17.124728+00:00       0          쥬카           zucca
# 1   2019-11-26 07:11:17.698582+00:00       0          자라            zara
# 2   2019-11-26 07:11:18.084561+00:00       0  예스터데이즈투모로우  ystrdy's tmrrw
# ...

# %%
engine.table_names()
# Out:
# ['BMcomp_Dat_TB',
#  'DB_Info_TB',
#  'DB_info_TB_Q1',
#  'Display_Code_TB',
#  'EcoModel_Detail_TB',
#  'EcoModel_Factor_TB',
#  'EcoModel_Idx_TB',
#  'EcoModel_Mast_TB',
#  'Factor_Dat_TB',
#  'Factor_IC_TB',
#  'Factor_Mast_TB',
#  'FixedRiskBudget_TB',
#  'Fund_Beneficiary_TB',
#  'Fund_Detail_TB',
#  'Fund_IsinHist_TB',
#  'Fund_Mast_TB',
#  'Fund_PLdecompose_TB',
#  'Fund_Result_TB',
#  'Fund_RiskBudget_TB',
#  'Fund_RiskBudget_TB2',
#  'Fund_RiskBudget_TB3',
#  'Fund_Sensitivity_TB',
#  'Fund_TempTrade_TB',
#  'Fund_Universe_Hist',
#  'Fund_Universe_TB',
#  'Fund_Universe_TB_temp',
#  'Fundamental_Data_TB',
#  'Fundamental_Mast_TB',
#  'Index_Bond_Dat_TB',
#  'Index_ETF_Dat_TB',
#  'Index_Idx_Dat_TB',
#  'Index_Mapping_TB',
#  'Index_Mast_TB',
#  'Index_Sensitivity_TB',
#  'Macro_Dictionary_TB',
#  'Macro_IdxComp_TB',
#  'Macro_Mast_TB',
#  'Macro_Schedule_TB',
#  'MktComment_Hist_TB',
#  'Model_Detail_TB',
#  'Model_History_TB',
#  'Model_Result_TB',
#  'Otherfund_Asset_TB',
# ...
